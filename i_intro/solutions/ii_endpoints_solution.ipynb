# %% [markdown]
# # 1. Import libraries

# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

from helpers import messages_for_summarization, summarize, get_contents

# %% [markdown]
# # 2. Solution

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %% [markdown]
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI

# %%
system_prompt = """
    You are an assistant that analyzes the contents of a website \
    and provides a short summary, ignoring text that might be navigation related. \
    Respond in markdown.
"""

user_prompt = """
    Here are the contents of the website \n
"""

# %%
request = messages_for_summarization(
    system_prompt,
    user_prompt,
    get_contents("https://www.alberteinstein.com/")
)

request
# Out:
# [{'role': 'system',
#   'content': '\n    You are an assistant that analyzes the contents of a website     and provides a short summary, ignoring text that might be navigation related.     Respond in markdown.\n'},
#  {'role': 'user',
# ...

# %%
response = summarize(ollama, request, request)

response
# Out:
# "**Summary of Albert Einstein's Biography**\n\nAlbert Einstein was a renowned theoretical physicist and one of the most influential scientists in human history. His groundbreaking theories on relativity and mass/energy equivalence (E = mc^2) revolutionized our understanding of the world. He was also an accomplished philosopher and humanist, with witty and insightful quotes that are widely used today.\n\n**Key Achievements:**\n\n* Developed the general theory of relativity\n* Received the Nobel Prize in Physics in 1921 for his services to theoretical physics\n* Made significant contributions to quantum mechanics\n\n**Einstein's Legacy:**\nHis name and image are instantly recognizable worldwide, reflecting his profound impact on scientific thought and culture."
